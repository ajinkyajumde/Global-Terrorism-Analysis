# %% [markdown]
# <a href="https://colab.research.google.com/github/ajinkyajumde/Global-Terrorism-Analysis/blob/main/Untitled1_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.</b>
#
# # <b> Explore and analyze the data to discover key findings pertaining to terrorist activities. </b>

# %%
pip install squarify

# %%
pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0 MB 5.3 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 32.0 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 52.0 MB/s
# ...

# %%
#importing the required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
from wordcloud import WordCloud

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path='/content/drive/MyDrive/Almabetter projects/Global Terrorism Analysis/Global Terrorism Data.csv'
gt=pd.read_csv(path,encoding="ISO-8859-1")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
gt.head(5)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
gt.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505644
# std    1.325955e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
gt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
gt.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
country=gt.groupby('country_txt')['iyear'].count().reset_index(name='Number of events')
c=country.sort_values(by='Number of events',ascending=False).head(10)
c
# Out:
#         country_txt  Number of events
# 84             Iraq             24636
# 134        Pakistan             14368
# 0       Afghanistan             12731
# 80            India             11960
# 35         Colombia              8306
# 140     Philippines              6908
# 139            Peru              6096
# 52      El Salvador              5320
# 188  United Kingdom              5235
# 183          Turkey              4292

# %% [markdown]
# ## **Here we have the top 10 countries in terms of number of terrorist activities.**

# %%
import squarify
plt.figure(figsize=(25,10))
colors=['#fae588','#f79d65','#f9dc5c','#e8ac65','#e76f51','#ef233c','#b7094c']
sns.set_style(style="whitegrid") # set seaborn plot style
sizes= c['Number of events'].values# proportions of the categories
label=c['country_txt']
squarify.plot(sizes=sizes, label=label, alpha=0.8,color=colors)
plt.title('Treemap for countries with maximum terrorist activities',fontweight ='bold', fontsize = 20)
plt.axis('off')

plt.show()

# %%
att=gt.groupby('attacktype1_txt')['iyear'].count().reset_index(name='Number of events')
att.rename(columns = {'attacktype1_txt' : 'Attack type'},inplace=True)
att.sort_values(by='Number of events',ascending=False).head(10)
# Out:
#                            Attack type  Number of events
# 2                    Bombing/Explosion             88255
# 0                        Armed Assault             42669
# 1                        Assassination             19312
# 6          Hostage Taking (Kidnapping)             11158
# 3       Facility/Infrastructure Attack             10356
# 8                              Unknown              7276
# 7                      Unarmed Assault              1015
# 5  Hostage Taking (Barricade Incident)               991
# 4                            Hijacking               659

# %%
# Figure Size
fig = plt.figure(figsize =(20, 10))
 
# Horizontal Bar Plot
plt.bar(att['Attack type'], att['Number of events'])
plt.title('Attack type Vs Number of events',fontweight ='bold', fontsize = 20)
plt.xlabel('Attack type', fontweight ='bold', fontsize = 15)
plt.ylabel('Number of events', fontweight ='bold', fontsize = 15)
 
# Show Plot
plt.show()

# %%
r=gt.groupby('region_txt')['iyear'].count().reset_index(name='Number of events')
rs=r.sort_values(by='Number of events',ascending=False)

# %%
rs
# Out:
#                      region_txt  Number of events
# 5    Middle East & North Africa             50474
# 8                    South Asia             44974
# 7                 South America             18978
# 10           Sub-Saharan Africa             17550
# 11               Western Europe             16639
# 9                Southeast Asia             12485
# 1   Central America & Caribbean             10344
# 4                Eastern Europe              5144
# 6                 North America              3456
# 3                     East Asia               802
# 2                  Central Asia               563
# 0         Australasia & Oceania               282

# %%
b=gt.groupby(['region_txt','attacktype1_txt'])['iyear'].count().unstack()

# %%
sns.set_theme(style="whitegrid")
plt.figure(figsize=(30,10))
plt.title('Region wise distrubution of attacks based on attack type',fontweight ='bold', fontsize = 20)
plt.xlabel('Region', fontweight ='bold', fontsize = 15)
plt.ylabel('Number of events', fontweight ='bold', fontsize = 15)
sns.lineplot(data=b, palette="tab10", linewidth=2.5)

# %%
gt['year_range']=gt.apply((lambda x: '1970-1980' if x['iyear']<=1980 else '1981-1990' if x['iyear']>1980 and x['iyear']<1991 else '1991-2000' if x['iyear']>1990 and x['iyear']<2001 else'2001-2010' if x['iyear']>2000 and x['iyear']<2011 else '2011-2022'),axis=1)

# %%
year_wise=gt.groupby('year_range')['iyear'].count().reset_index(name='count')
year_wise
# Out:
#   year_range  count
# 0  1970-1980  12576
# 1  1981-1990  32385
# 2  1991-2000  26689
# 3  2001-2010  28052
# 4  2011-2022  81989

# %%
heat=gt.groupby(['year_range','attacktype1_txt'])['iyear'].count().unstack()
heat
# Out:
# attacktype1_txt  Armed Assault  Assassination  Bombing/Explosion  \
# year_range
# 1970-1980                 1998           2617               5317
# 1981-1990                 8005           5424              14871
# 1991-2000                 6742           4427              10072
# 2001-2010                 6945           1704              15044
# 2011-2022                18979           5140              42951
#
# attacktype1_txt  Facility/Infrastructure Attack  Hijacking  \
# year_range
# 1970-1980                                  1265         75
# 1981-1990                                  1583        106
# 1991-2000                                  1946        171
# 2001-2010                                  1516         88
# 2011-2022                                  4046        219
#
# attacktype1_txt  Hostage Taking (Barricade Incident)  \
# year_range
# 1970-1980                                        221
# 1981-1990                                        298
# ...

# %%
b=gt.groupby('iyear')['eventid'].count().reset_index(name='count')
# Out:
#     iyear  count
# 0    1970    651
# 1    1971    471
# 2    1972    568
# 3    1973    473
# 4    1974    581
# 5    1975    740
# 6    1976    923
# 7    1977   1319
# 8    1978   1526
# 9    1979   2662
# 10   1980   2662
# 11   1981   2586
# 12   1982   2544
# 13   1983   2870
# 14   1984   3495
# 15   1985   2915
# 16   1986   2860
# 17   1987   3183
# 18   1988   3721
# 19   1989   4324
# 20   1990   3887
# 21   1991   4683
# 22   1992   5071
# 23   1994   3456
# 24   1995   3081
# 25   1996   3058
# 26   1997   3197
# 27   1998    934
# 28   1999   1395
# 29   2000   1814
# 30   2001   1906
# 31   2002   1333
# 32   2003   1278
# 33   2004   1166
# 34   2005   2017
# 35   2006   2758
# 36   2007   3242
# 37   2008   4805
# 38   2009   4721
# 39   2010   4826
# 40   2011   5076
# 41   2012   8522
# 42   2013  12036
# 43   2014  16903
# 44   2015  14965
# 45   2016  13587
# 46   2017  10900

# %%
att=gt.groupby(['region_txt','year_range'])['iyear'].count().unstack()
att
# Out:
# year_range                   1970-1980  1981-1990  1991-2000  2001-2010  \
# region_txt
# Australasia & Oceania             23.0       89.0      101.0       23.0
# Central America & Caribbean     1988.0     6736.0     1545.0       46.0
# Central Asia                       NaN        NaN      356.0      136.0
# East Asia                         79.0      208.0      336.0       70.0
# Eastern Europe                    27.0      100.0     1238.0     1353.0
# Middle East & North Africa      1527.0     2940.0     5201.0     9304.0
# North America                   1671.0      520.0      658.0      253.0
# South America                   1328.0    10455.0     4837.0     1147.0
# South Asia                        63.0     3460.0     4596.0     9650.0
# Southeast Asia                   281.0     1347.0     1551.0     2924.0
# Sub-Saharan Africa               300.0     1968.0     2429.0     1860.0
# Western Europe                  5289.0     4562.0     3841.0     1286.0
#
# ...

# %%
typ=gt.groupby('targtype1_txt')['iyear'].count().reset_index(name='Number of events')
maxt=typ.sort_values(by='Number of events',ascending=False).head(3)
mint=typ.sort_values(by='Number of events',ascending=True).head(3)

# %%
typ.sort_values(by='Number of events',ascending=False)
# Out:
#                      targtype1_txt  Number of events
# 13     Private Citizens & Property             43511
# 9                         Military             27984
# 12                          Police             24506
# 6             Government (General)             21283
# 2                         Business             20669
# 18                  Transportation              6799
# 20                       Utilities              6023
# 19                         Unknown              5898
# 14  Religious Figures/Institutions              4440
# 3          Educational Institution              4322
# 5          Government (Diplomatic)              3573
# 16    Terrorists/Non-State Militia              3039
# 7              Journalists & Media              2948
# 21         Violent Political Party              1866
# 1              Airports & Aircraft              1343
# 15               Telecommunication              1009
# 10                             NGO               970
# ...

# %%
maxt
# Out:
#                   targtype1_txt  Number of events
# 13  Private Citizens & Property             43511
# 9                      Military             27984
# 12                       Police             24506

# %%
mint
# Out:
#            targtype1_txt  Number of events
# 11                 Other               137
# 0       Abortion Related               263
# 4   Food or Water Supply               317

# %%
targ=gt.groupby(['targtype1_txt','attacktype1_txt'])['iyear'].count().unstack()

# %%
targ.fillna(0,inplace=True)
targ
# Out:
# attacktype1_txt                 Armed Assault  Assassination  \
# targtype1_txt
# Abortion Related                          8.0            9.0
# Airports & Aircraft                     104.0           16.0
# Business                               2389.0          958.0
# Educational Institution                 601.0          360.0
# Food or Water Supply                     42.0            0.0
# Government (Diplomatic)                 641.0          399.0
# Government (General)                   3451.0         5982.0
# Journalists & Media                     381.0          749.0
# Maritime                                 77.0           11.0
# Military                              11102.0         1591.0
# NGO                                     226.0           87.0
# Other                                    35.0            3.0
# Police                                 8885.0         2851.0
# Private Citizens & Property           10848.0         4234.0
# ...

# %%
n=gt.groupby(['attacktype1','attacktype1_txt'])['iyear'].count().reset_index(name='count')
n.drop('count',axis=1)
# Out:
#    attacktype1                      attacktype1_txt
# 0            1                        Assassination
# 1            2                        Armed Assault
# 2            3                    Bombing/Explosion
# 3            4                            Hijacking
# 4            5  Hostage Taking (Barricade Incident)
# 5            6          Hostage Taking (Kidnapping)
# 6            7       Facility/Infrastructure Attack
# 7            8                      Unarmed Assault
# 8            9                              Unknown

# %%
worldmap = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))

# Creating axes and plotting world map
fig, ax = plt.subplots(figsize=(35, 10))
worldmap.plot(color="lightgrey", ax=ax)

# Plotting our Impact Energy data with a color map
x = gt['longitude']
y = gt['latitude']
z = gt['attacktype1']
plt.scatter(x, y, s=20*z, c=z, alpha=0.6, vmin=0, vmax=10,
            cmap='autumn')
plt.colorbar(label='Attack intensity based on attack type')

# Creating axis limits and title
plt.xlim([-180, 180])
plt.ylim([-90, 90])


plt.title('Attacks Worldwide',fontsize = 20)
plt.xlabel("Longitude",fontsize = 10)
plt.ylabel("Latitude",fontsize = 10)
plt.show()

# %%
lst=list(gt['attacktype1_txt'])
lst=set(lst)
lst=list(lst)
lst
# Out:
# ['Hijacking',
#  'Hostage Taking (Barricade Incident)',
#  'Unarmed Assault',
#  'Assassination',
#  'Bombing/Explosion',
#  'Unknown',
#  'Armed Assault',
#  'Facility/Infrastructure Attack',
#  'Hostage Taking (Kidnapping)']

# %%
words = " ".join(str(each) for each in lst)

# %%
wordcloud = WordCloud(width=1980, height=1080, colormap="Paired_r",max_words=100, background_color="white").generate(words)
plt.figure(figsize=(10,6))
plt.figure(figsize=(15,10))
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
gt['success_count']=gt.apply((lambda x : 1 if x['success']==1 else 0),axis=1)
gt['unsuccess_count']=gt.apply((lambda x : 1 if x['success']==0 else 0),axis=1)

# %%
gt[['success_count','unsuccess_count']].sum().reset_index(name='Total')
# Out:
#              index   Total
# 0    success_count  161632
# 1  unsuccess_count   20059

# %%
c=gt.groupby('region_txt')[['success_count','unsuccess_count']].sum().reset_index()

# %%
c
# Out:
#                      region_txt  success_count  unsuccess_count
# 0         Australasia & Oceania            240               42
# 1   Central America & Caribbean           9979              365
# 2                  Central Asia            505               58
# 3                     East Asia            680              122
# 4                Eastern Europe           4437              707
# 5    Middle East & North Africa          44319             6155
# 6                 North America           2894              562
# 7                 South America          17620             1358
# 8                    South Asia          39369             5605
# 9                Southeast Asia          11151             1334
# 10           Sub-Saharan Africa          16277             1273
# 11               Western Europe          14161             2478

# %%
x=list(c['region_txt'])
y=list(c['success_count'])
y1=list(c['unsuccess_count'])

fig, ax1 = plt.subplots(figsize=(30, 8),)

ax2 = ax1.twinx()
ax1.bar(x, y,color="maroon")
ax2.plot(x, y1, 'o-', color="green" )
ax1.set_title('Sucessful and Unsuccessful Attempts Across the Regions',fontsize = 20)
ax1.set_xlabel('Region',fontsize = 10)
ax1.set_ylabel('Success Count', color='r',fontsize = 10)
ax2.set_ylabel('Unsuccess Count', color='g',fontsize = 10)
plt.grid(False)
plt.show()

# %%
india=gt[(gt.country_txt=='India')]
india.head()
# Out:
#            eventid  iyear  imonth  iday approxdate  extended resolution  \
# 1186  1.972020e+11   1972       2    22        NaN         0        NaN
# 2764  1.975010e+11   1975       1     2        NaN         0        NaN
# 3857  1.976050e+11   1976       5    26        NaN         0        NaN
# 5327  1.977090e+11   1977       9    28        NaN         0        NaN
# 7337  1.979010e+11   1979       1    13        NaN         0        NaN
#
#       country country_txt  region  ... scite3  \
# 1186       92       India       6  ...    NaN
# 2764       92       India       6  ...    NaN
# 3857       92       India       6  ...    NaN
# 5327       92       India       6  ...    NaN
# 7337       92       India       6  ...    NaN
#
#                                       dbsource INT_LOG  INT_IDEO  INT_MISC  \
# 1186                              Hijacking DB       1         1         1
# 2764  UMD Encyclopedia of World Terrorism 2012       0         0         0
# ...

# %%
india.groupby(['iyear','attacktype1_txt'])['region'].count().unstack()
# Out:
# attacktype1_txt  Armed Assault  Assassination  Bombing/Explosion  \
# iyear
# 1972                       NaN            NaN                NaN
# 1975                       NaN            NaN                1.0
# 1976                       NaN            NaN                1.0
# 1977                       NaN            NaN                NaN
# 1979                       9.0            5.0                3.0
# 1980                       2.0            3.0                5.0
# 1981                       NaN            4.0                9.0
# 1982                       1.0            4.0                4.0
# 1983                       1.0           15.0               26.0
# 1984                      14.0           58.0               66.0
# 1985                       1.0           19.0               16.0
# 1986                      35.0           37.0                9.0
# 1987                      57.0           69.0               23.0
# ...

# %%
ind=india.groupby(['year_range','attacktype1_txt'])['region'].count().unstack()
ind
# Out:
# attacktype1_txt  Armed Assault  Assassination  Bombing/Explosion  \
# year_range
# 1970-1980                 11.0            8.0               10.0
# 1981-1990                387.0          596.0              443.0
# 1991-2000                485.0          206.0              638.0
# 2001-2010               1008.0          128.0             1314.0
# 2011-2022               1293.0          291.0             2420.0
#
# attacktype1_txt  Facility/Infrastructure Attack  Hijacking  \
# year_range
# 1970-1980                                   2.0        2.0
# 1981-1990                                  33.0       12.0
# 1991-2000                                  75.0        5.0
# 2001-2010                                 221.0       12.0
# 2011-2022                                 665.0       12.0
#
# attacktype1_txt  Hostage Taking (Barricade Incident)  \
# year_range
# 1970-1980                                        NaN
# 1981-1990                                        NaN
# ...

# %%
plt.figure(figsize=(30,10))
plt.title('Year Vs Number of events based on attack type',fontweight ='bold', fontsize = 20)
plt.xlabel('Year Range', fontweight ='bold', fontsize = 15)
plt.ylabel('Number of events', fontweight ='bold', fontsize = 15)
sns.lineplot(data=ind)

# %%
i=india.groupby('attacktype1_txt')['iyear'].count().reset_index(name='count')
i
# Out:
#                        attacktype1_txt  count
# 0                        Armed Assault   3184
# 1                        Assassination   1229
# 2                    Bombing/Explosion   4825
# 3       Facility/Infrastructure Attack    996
# 4                            Hijacking     43
# 5  Hostage Taking (Barricade Incident)     44
# 6          Hostage Taking (Kidnapping)   1184
# 7                      Unarmed Assault    143
# 8                              Unknown    312

# %%
plt.figure(figsize=(25,10))

colors=['#fae588','#f79d65','#f9dc5c','#e8ac65','#e76f51','#ef233c','#b7094c']
sns.set_style(style="whitegrid") # set seaborn plot style
sizes= i['count'].values# proportions of the categories
label=i['attacktype1_txt']
squarify.plot(sizes=sizes, label=label, alpha=0.8,color=colors)
plt.title('Treemap for Attack Types in India Based on Number of Events Reported',fontweight ='bold', fontsize = 20)
plt.axis('off')

plt.show()

# %%
india[['success_count','unsuccess_count']].sum().reset_index(name='Total')
# Out:
#              index  Total
# 0    success_count  10280
# 1  unsuccess_count   1680

# %%
type=india.groupby('targtype1_txt')['iyear'].count().reset_index(name='Number of events')

# %%
type.sort_values(by='Number of events',ascending=False,inplace=True)
type.head(5)
# Out:
#                      targtype1_txt  Number of events
# 12     Private Citizens & Property              3144
# 11                          Police              2299
# 5             Government (General)              1727
# 1                         Business              1131
# 8                         Military               916
# 17                  Transportation               831
# 18                         Unknown               598
# 2          Educational Institution               297
# 20         Violent Political Party               234
# 13  Religious Figures/Institutions               214
# 15    Terrorists/Non-State Militia               143
# 14               Telecommunication               139
# 6              Journalists & Media                87
# 19                       Utilities                86
# 16                        Tourists                30
# 0              Airports & Aircraft                28
# 9                              NGO                20
# ...
